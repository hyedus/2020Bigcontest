# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "maindata/01_제공데이터/"
df = pd.read_excel(path+'2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터.xlsx',skiprows = [0] )
df
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00        NaN  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00        NaN  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0
# 3                 테이트 여성 셀린니트3종  의류  39900  6955000.0
# ...

# %%
rate = pd.read_excel(path+"2020 빅콘테스트 데이터분석분야-챔피언리그_시청률 데이터.xlsx", skiprows = [0])
rate
# Out:
#                      시간대  2019-01-01  2019-01-02  2019-01-03  2019-01-04  \
# 0                  02:00       0.000       0.000       0.000       0.000
# 1                  02:01       0.000       0.000       0.000       0.000
# 2                  02:02       0.000       0.000       0.000       0.000
# 3                  02:03       0.000       0.000       0.014       0.000
# 4                  02:04       0.000       0.000       0.000       0.000
# ...                  ...         ...         ...         ...         ...
# 1436               01:56       0.000       0.000       0.000       0.000
# 1437               01:57       0.000       0.000       0.000       0.000
# 1438               01:58       0.000       0.000       0.000       0.000
# 1439               01:59       0.000       0.000       0.000       0.000
# 1440  월화수목금토일02:00-01:59       0.004       0.006       0.002       0.003
#
#       2019-01-05  2019-01-06  2019-01-07  2019-01-08  2019-01-09  ...  \
# ...

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Columns: 367 entries, 시간대 to 2019-01-01 to 2019-12-31
# dtypes: float64(366), object(1)
# memory usage: 4.0+ MB

# %%
rate.describe()
# Out:
#         2019-01-01   2019-01-02   2019-01-03   2019-01-04   2019-01-05  \
# count  1441.000000  1441.000000  1441.000000  1441.000000  1441.000000
# mean      0.003681     0.005564     0.001731     0.002658     0.002079
# std       0.008067     0.012898     0.006213     0.008908     0.007124
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.005000     0.000000     0.000000     0.000000     0.000000
# max       0.069000     0.073000     0.073000     0.059000     0.070000
#
#         2019-01-06   2019-01-07   2019-01-08   2019-01-09   2019-01-10  ...  \
# count  1441.000000  1441.000000  1441.000000  1441.000000  1441.000000  ...
# mean      0.002858     0.002703     0.002152     0.002730     0.001947  ...
# std       0.008478     0.006594     0.006987     0.008164     0.008277  ...
# ...

# %%
rate.columns
# Out:
# Index(['시간대', '2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#        '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09',
#        ...
#        '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26', '2019-12-27',
#        '2019-12-28', '2019-12-29', '2019-12-30', '2019-12-31',
#        '2019-01-01 to 2019-12-31'],
#       dtype='object', length=367)

# %%
rate['시간대'].unique()
# Out:
# array(['02:00', '02:01', '02:02', ..., '01:58', '01:59',
#        '월화수목금토일02:00-01:59'], dtype=object)

# %%
rate[['시간대']]
# Out:
#                      시간대
# 0                  02:00
# 1                  02:01
# 2                  02:02
# 3                  02:03
# 4                  02:04
# ...                  ...
# 1436               01:56
# 1437               01:57
# 1438               01:58
# 1439               01:59
# 1440  월화수목금토일02:00-01:59
#
# [1441 rows x 1 columns]

# %%
mean_ = rate.iloc[1440:,:]
mean_.
# Out:
#                      시간대  2019-01-01  2019-01-02  2019-01-03  2019-01-04  \
# 1440  월화수목금토일02:00-01:59       0.004       0.006       0.002       0.003
#
#       2019-01-05  2019-01-06  2019-01-07  2019-01-08  2019-01-09  ...  \
# 1440       0.002       0.003       0.003       0.002       0.003  ...
#
#       2019-12-23  2019-12-24  2019-12-25  2019-12-26  2019-12-27  2019-12-28  \
# 1440        0.01       0.006       0.006       0.007       0.004       0.006
#
#       2019-12-29  2019-12-30  2019-12-31  2019-01-01 to 2019-12-31
# 1440       0.004       0.005       0.005                     0.004
#
# [1 rows x 367 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38309 entries, 0 to 38308
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   방송일시    38309 non-null  datetime64[ns]
#  1   노출(분)   21525 non-null  float64
#  2   마더코드    38309 non-null  int64
#  3   상품코드    38309 non-null  int64
#  4   상품명     38309 non-null  object
#  5   상품군     38309 non-null  object
#  6   판매단가    38309 non-null  int64
#  7   취급액     37372 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.3+ MB

# %%
df.describe(include = 'all')

# %%
df.describe()

# %%
check = df[['판매단가','취급액']].copy()
check

# %%
check[check['취급액'].isna()].describe()

# %%
ncost = df[df['판매단가'] == 0]
ncost

# %%
ncost.info()

# %%
ncost.describe(include='all')

# %%
ncost["상품명"].unique()

# %%
df["상품군"].value_counts()

# %%
df[df["상품군"]=="잡화"][['상품명']].value_counts()

# %%
df[df["판매단가"] != 0][['판매단가']].value_counts()

# %%
df[df["판매단가"] >= 1390000]["상품명"].unique()

# %%
df.columns

# %%
df.sort_values("취급액")
